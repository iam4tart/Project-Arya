# %%
import numpy as np 
import pandas as pd
import operator
import os
import chart_studio.tools as tls

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from matplotlib.backend_bases import RendererBase
from scipy import signal
from scipy.io import wavfile

import os
import numpy as np

from PIL import Image

from scipy.fftpack import fft
import librosa
import librosa.display

import plotly as py
tls.set_credentials_file(username='iam4tart',api_key='Docq9bPOpIqBxnDmPIxJ')

import chart_studio.plotly as py
import plotly.graph_objs as go

import cufflinks as cf
import IPython.display as ipd
# Out:
# /var/folders/bq/chj86vfj3c7f11203j8dzrtm0000gn/T/ipykernel_13207/883414657.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /Users/pabitraghosh/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def get_files_with_features(path):
    data_ = []
    count = {}
    files = os.listdir(path)
    for file in files:
        labels = file.split("-")[:3]
        if len(labels) < 3:
            continue 
        data = {
            "keyword": labels[0],
            "stress": labels[2],
            "environment": labels[1],
            "path": os.path.join(path, file)
        }
        for label in labels:
            if label not in count.keys():
                count[label] = 1
            else:
                count[label] += 1

        data_.append(data)

    if data_:
        df = pd.DataFrame(data_)
    else:
        df = pd.DataFrame(columns=['keyword', 'stress', 'environment', 'path'])
    return data_, count, df

# Example usage
path = '/Users/pabitraghosh/convertaudio/AudioToSpectogram/spectrograms'
dataset_with_features, count, df_with_features = get_files_with_features(path)
print(df_with_features.head())
# Out:
#       keyword stress environment  \
# 0          go   calm        safe
# 1        help   calm        safe
# 2  background   calm        safe
# 3  background   calm        safe
# 4         yes  happy        safe
#
#                                                 path
# 0  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 1  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 2  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 3  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 4  /Users/pabitraghosh/convertaudio/AudioToSpecto...

# %%
df_with_features.count()
# Out:
# keyword        15555
# stress         15555
# environment    15555
# path           15555
# dtype: int64

# %%
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
images = []
labels = []

for index, row in df_with_features.iterrows():
    image = cv2.imread(row['path'])
    image = cv2.resize(image, (64, 64))  # Resize images to a common size
    images.append(image)
    labels.append(row['stress'])

images = np.array(images)
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming y_train and y_test are your label arrays

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the training labels (y_train)
y_train_encoded = label_encoder.fit_transform(y_train)

# Transform the test labels (y_test) using the fitted encoder
y_test_encoded = label_encoder.transform(y_test)

# %%
num_classes = df_with_features['stress'].nunique()
print(num_classes)
# Out:
# 5

# %%
from keras.applications import ResNet50
from keras.layers import GlobalAveragePooling2D, Dropout

# Load pre-trained ResNet50 model (excluding the top layer)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze the base model layers
base_model.trainable = False

# Add custom layers on top of the base model
model1 = Sequential()
model1.add(base_model)
model1.add(GlobalAveragePooling2D())
model1.add(Dense(256, activation='relu'))
model1.add(Dropout(0.5))  # Add dropout for regularization
model1.add(Dense(num_classes, activation='softmax'))  # Assuming num_classes = 5

# Compile the model
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history1 = model1.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model1.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 37s 99ms/step - accuracy: 0.6064 - loss: 1.2623 - val_accuracy: 0.7108 - val_loss: 0.7960 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6837 - loss: 0.8471 - val_accuracy: 0.7269 - val_loss: 0.7577 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 111ms/step - accuracy: 0.6992 - loss: 0.8151 - val_accuracy: 0.7285 - val_loss: 0.7284 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.7137 - loss: 0.7683 - val_accuracy: 0.7341 - val_loss: 0.7092 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 37s 105ms/step - accuracy: 0.7291 - loss: 0.7250 - val_accuracy: 0.7422 - val_loss: 0.7081 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 110ms/step - accuracy: 0.7328 - loss: 0.7096 - val_accuracy: 0.7325 - val_loss: 0.6949 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 107ms/step - accuracy: 0.7310 - loss: 0.6956 - val_accuracy: 0.7542 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.7505 - loss: 0.6595 - val_accuracy: 0.7550 - val_loss: 0.6700 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 112ms/step - accuracy: 0.7448 - loss: 0.6621 - val_accuracy: 0.7566 - val_loss: 0.6668 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 109ms/step - accuracy: 0.7632 - loss: 0.6137 - val_accuracy: 0.7606 - val_loss: 0.6413 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 109ms/step - accuracy: 0.7717 - loss: 0.5985 - val_accuracy: 0.7478 - val_loss: 0.6751 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.7721 - loss: 0.5893 - val_accuracy: 0.7502 - val_loss: 0.6627 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.7775 - loss: 0.5682 - val_accuracy: 0.7590 - val_loss: 0.6592 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 110ms/step - accuracy: 0.7845 - loss: 0.5571 - val_accuracy: 0.7631 - val_loss: 0.6664 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 40s 115ms/step - accuracy: 0.7859 - loss: 0.5416 - val_accuracy: 0.7606 - val_loss: 0.6675 - learning_rate: 0.0010
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 113ms/step - accuracy: 0.8073 - loss: 0.5052 - val_accuracy: 0.7622 - val_loss: 0.6503 - learning_rate: 1.0000e-04
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 60s 172ms/step - accuracy: 0.8171 - loss: 0.4642 - val_accuracy: 0.7631 - val_loss: 0.6547 - learning_rate: 1.0000e-04
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 67s 191ms/step - accuracy: 0.8259 - loss: 0.4415 - val_accuracy: 0.7679 - val_loss: 0.6570 - learning_rate: 1.0000e-04
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 61s 174ms/step - accuracy: 0.8348 - loss: 0.4233 - val_accuracy: 0.7671 - val_loss: 0.6483 - learning_rate: 1.0000e-04
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 60s 170ms/step - accuracy: 0.8294 - loss: 0.4253 - val_accuracy: 0.7663 - val_loss: 0.6571 - learning_rate: 1.0000e-04
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 58s 167ms/step - accuracy: 0.8342 - loss: 0.4199 - val_accuracy: 0.7695 - val_loss: 0.6596 - learning_rate: 1.0000e-04
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 59s 168ms/step - accuracy: 0.8441 - loss: 0.3987 - val_accuracy: 0.7695 - val_loss: 0.6479 - learning_rate: 1.0000e-04
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 58s 165ms/step - accuracy: 0.8411 - loss: 0.4018 - val_accuracy: 0.7687 - val_loss: 0.6637 - learning_rate: 1.0000e-04
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 58s 167ms/step - accuracy: 0.8468 - loss: 0.3887 - val_accuracy: 0.7711 - val_loss: 0.6535 - learning_rate: 1.0000e-04
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 59s 169ms/step - accuracy: 0.8470 - loss: 0.3908 - val_accuracy: 0.7711 - val_loss: 0.6593 - learning_rate: 1.0000e-04
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 64s 184ms/step - accuracy: 0.8433 - loss: 0.3872 - val_accuracy: 0.7703 - val_loss: 0.6535 - learning_rate: 1.0000e-04
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39937s 114s/step - accuracy: 0.8494 - loss: 0.3842 - val_accuracy: 0.7759 - val_loss: 0.6637 - learning_rate: 1.0000e-04
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 357s 1s/step - accuracy: 0.8474 - loss: 0.3878 - val_accuracy: 0.7727 - val_loss: 0.6613 - learning_rate: 1.0000e-04
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 942s 3s/step - accuracy: 0.8510 - loss: 0.3688 - val_accuracy: 0.7703 - val_loss: 0.6780 - learning_rate: 1.0000e-04
# Epoch 30/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 45s 128ms/step - accuracy: 0.8585 - loss: 0.3657 - val_accuracy: 0.7687 - val_loss: 0.6669 - learning_rate: 1.0000e-04
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - accuracy: 0.7557 - loss: 0.6512
# Test accuracy: 0.7630986571311951

# %%
# Plot training & validation accuracy values
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from keras.applications import EfficientNetB0 # Choose the desired EfficientNet variant
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Define the EfficientNet model
base_model1 = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze base model layers
base_model1.trainable = False

model2 = Sequential()
model2.add(base_model1)
model2.add(GlobalAveragePooling2D())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.5))  # Add dropout for regularization
model2.add(Dense(num_classes, activation='softmax'))


# Compile the model
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history2 = model2.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model2.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.5922 - loss: 1.1226 - val_accuracy: 0.6731 - val_loss: 0.9087 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6520 - loss: 0.9566 - val_accuracy: 0.6908 - val_loss: 0.8546 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6618 - loss: 0.9165 - val_accuracy: 0.6884 - val_loss: 0.8456 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.6684 - loss: 0.8992 - val_accuracy: 0.6867 - val_loss: 0.8475 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6774 - loss: 0.8693 - val_accuracy: 0.7044 - val_loss: 0.8225 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6819 - loss: 0.8621 - val_accuracy: 0.7213 - val_loss: 0.7979 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.6912 - loss: 0.8406 - val_accuracy: 0.7181 - val_loss: 0.7840 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.6926 - loss: 0.8312 - val_accuracy: 0.7076 - val_loss: 0.7954 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6989 - loss: 0.8244 - val_accuracy: 0.7141 - val_loss: 0.7814 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6986 - loss: 0.8144 - val_accuracy: 0.7221 - val_loss: 0.7811 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.6977 - loss: 0.8171 - val_accuracy: 0.7141 - val_loss: 0.7955 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7038 - loss: 0.7872 - val_accuracy: 0.7237 - val_loss: 0.7857 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7055 - loss: 0.8052 - val_accuracy: 0.7261 - val_loss: 0.7761 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7107 - loss: 0.7780 - val_accuracy: 0.7165 - val_loss: 0.7676 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 52ms/step - accuracy: 0.7047 - loss: 0.7945 - val_accuracy: 0.7349 - val_loss: 0.7603 - learning_rate: 0.0010
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.7156 - loss: 0.7673 - val_accuracy: 0.7341 - val_loss: 0.7716 - learning_rate: 0.0010
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7191 - loss: 0.7647 - val_accuracy: 0.7261 - val_loss: 0.7594 - learning_rate: 0.0010
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 842s 2s/step - accuracy: 0.7082 - loss: 0.7752 - val_accuracy: 0.7333 - val_loss: 0.7470 - learning_rate: 0.0010
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7231 - loss: 0.7452 - val_accuracy: 0.7237 - val_loss: 0.7645 - learning_rate: 0.0010
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7179 - loss: 0.7516 - val_accuracy: 0.7092 - val_loss: 0.7837 - learning_rate: 0.0010
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7151 - loss: 0.7631 - val_accuracy: 0.7269 - val_loss: 0.7593 - learning_rate: 0.0010
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7225 - loss: 0.7388 - val_accuracy: 0.7309 - val_loss: 0.7532 - learning_rate: 0.0010
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7273 - loss: 0.7306 - val_accuracy: 0.7365 - val_loss: 0.7403 - learning_rate: 0.0010
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7225 - loss: 0.7322 - val_accuracy: 0.7293 - val_loss: 0.7375 - learning_rate: 0.0010
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7286 - loss: 0.7329 - val_accuracy: 0.7309 - val_loss: 0.7577 - learning_rate: 0.0010
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7288 - loss: 0.7173 - val_accuracy: 0.7237 - val_loss: 0.7527 - learning_rate: 0.0010
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 47ms/step - accuracy: 0.7211 - loss: 0.7235 - val_accuracy: 0.7382 - val_loss: 0.7436 - learning_rate: 0.0010
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7376 - loss: 0.7019 - val_accuracy: 0.7470 - val_loss: 0.7379 - learning_rate: 0.0010
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7396 - loss: 0.7064 - val_accuracy: 0.7365 - val_loss: 0.7552 - learning_rate: 0.0010
# Epoch 30/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7561 - loss: 0.6710 - val_accuracy: 0.7422 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 31/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7536 - loss: 0.6591 - val_accuracy: 0.7390 - val_loss: 0.7369 - learning_rate: 1.0000e-04
# Epoch 32/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7611 - loss: 0.6544 - val_accuracy: 0.7422 - val_loss: 0.7323 - learning_rate: 1.0000e-04
# Epoch 33/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7497 - loss: 0.6602 - val_accuracy: 0.7430 - val_loss: 0.7322 - learning_rate: 1.0000e-04
# Epoch 34/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7647 - loss: 0.6318 - val_accuracy: 0.7406 - val_loss: 0.7303 - learning_rate: 1.0000e-04
# Epoch 35/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7502 - loss: 0.6545 - val_accuracy: 0.7406 - val_loss: 0.7284 - learning_rate: 1.0000e-04
# Epoch 36/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7547 - loss: 0.6511 - val_accuracy: 0.7414 - val_loss: 0.7289 - learning_rate: 1.0000e-04
# Epoch 37/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7643 - loss: 0.6377 - val_accuracy: 0.7454 - val_loss: 0.7274 - learning_rate: 1.0000e-04
# Epoch 38/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7618 - loss: 0.6468 - val_accuracy: 0.7382 - val_loss: 0.7320 - learning_rate: 1.0000e-04
# Epoch 39/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7631 - loss: 0.6400 - val_accuracy: 0.7446 - val_loss: 0.7267 - learning_rate: 1.0000e-04
# Epoch 40/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7602 - loss: 0.6396 - val_accuracy: 0.7470 - val_loss: 0.7293 - learning_rate: 1.0000e-04
# Epoch 41/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7619 - loss: 0.6273 - val_accuracy: 0.7438 - val_loss: 0.7283 - learning_rate: 1.0000e-04
# Epoch 42/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7543 - loss: 0.6493 - val_accuracy: 0.7470 - val_loss: 0.7258 - learning_rate: 1.0000e-04
# Epoch 43/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7660 - loss: 0.6258 - val_accuracy: 0.7438 - val_loss: 0.7242 - learning_rate: 1.0000e-04
# Epoch 44/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7650 - loss: 0.6290 - val_accuracy: 0.7446 - val_loss: 0.7257 - learning_rate: 1.0000e-04
# Epoch 45/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7546 - loss: 0.6426 - val_accuracy: 0.7446 - val_loss: 0.7248 - learning_rate: 1.0000e-04
# Epoch 46/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7638 - loss: 0.6457 - val_accuracy: 0.7438 - val_loss: 0.7264 - learning_rate: 1.0000e-04
# Epoch 47/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7582 - loss: 0.6398 - val_accuracy: 0.7422 - val_loss: 0.7235 - learning_rate: 1.0000e-04
# Epoch 48/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7679 - loss: 0.6253 - val_accuracy: 0.7422 - val_loss: 0.7241 - learning_rate: 1.0000e-04
# Epoch 49/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7628 - loss: 0.6267 - val_accuracy: 0.7486 - val_loss: 0.7275 - learning_rate: 1.0000e-04
# Epoch 50/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7620 - loss: 0.6171 - val_accuracy: 0.7454 - val_loss: 0.7240 - learning_rate: 1.0000e-04
# Epoch 51/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7623 - loss: 0.6286 - val_accuracy: 0.7390 - val_loss: 0.7287 - learning_rate: 1.0000e-04
# Epoch 52/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7631 - loss: 0.6302 - val_accuracy: 0.7462 - val_loss: 0.7219 - learning_rate: 1.0000e-04
# Epoch 53/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7649 - loss: 0.6321 - val_accuracy: 0.7486 - val_loss: 0.7244 - learning_rate: 1.0000e-04
# Epoch 54/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7726 - loss: 0.6137 - val_accuracy: 0.7446 - val_loss: 0.7254 - learning_rate: 1.0000e-04
# Epoch 55/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7619 - loss: 0.6259 - val_accuracy: 0.7438 - val_loss: 0.7182 - learning_rate: 1.0000e-04
# Epoch 56/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7667 - loss: 0.6275 - val_accuracy: 0.7462 - val_loss: 0.7217 - learning_rate: 1.0000e-04
# Epoch 57/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7669 - loss: 0.6194 - val_accuracy: 0.7430 - val_loss: 0.7245 - learning_rate: 1.0000e-04
# Epoch 58/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7683 - loss: 0.6111 - val_accuracy: 0.7470 - val_loss: 0.7221 - learning_rate: 1.0000e-04
# Epoch 59/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7711 - loss: 0.6233 - val_accuracy: 0.7406 - val_loss: 0.7181 - learning_rate: 1.0000e-04
# Epoch 60/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7686 - loss: 0.6193 - val_accuracy: 0.7462 - val_loss: 0.7235 - learning_rate: 1.0000e-04
# Epoch 61/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7724 - loss: 0.6225 - val_accuracy: 0.7462 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 62/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7737 - loss: 0.6057 - val_accuracy: 0.7406 - val_loss: 0.7241 - learning_rate: 1.0000e-04
# Epoch 63/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7703 - loss: 0.6143 - val_accuracy: 0.7422 - val_loss: 0.7248 - learning_rate: 1.0000e-04
# Epoch 64/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7690 - loss: 0.6176 - val_accuracy: 0.7454 - val_loss: 0.7185 - learning_rate: 1.0000e-04
# Epoch 65/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7672 - loss: 0.6148 - val_accuracy: 0.7414 - val_loss: 0.7200 - learning_rate: 1.0000e-04
# Epoch 66/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7647 - loss: 0.6185 - val_accuracy: 0.7422 - val_loss: 0.7206 - learning_rate: 1.0000e-04
# Epoch 67/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7717 - loss: 0.6214 - val_accuracy: 0.7430 - val_loss: 0.7227 - learning_rate: 1.0000e-04
# Epoch 68/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7640 - loss: 0.6104 - val_accuracy: 0.7446 - val_loss: 0.7228 - learning_rate: 1.0000e-04
# Epoch 69/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7666 - loss: 0.6229 - val_accuracy: 0.7430 - val_loss: 0.7234 - learning_rate: 1.0000e-04
# Epoch 70/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7768 - loss: 0.6016 - val_accuracy: 0.7414 - val_loss: 0.7196 - learning_rate: 1.0000e-04
# Epoch 71/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7713 - loss: 0.6077 - val_accuracy: 0.7446 - val_loss: 0.7209 - learning_rate: 1.0000e-04
# Epoch 72/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7727 - loss: 0.6023 - val_accuracy: 0.7422 - val_loss: 0.7196 - learning_rate: 1.0000e-04
# Epoch 73/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7808 - loss: 0.5871 - val_accuracy: 0.7422 - val_loss: 0.7214 - learning_rate: 1.0000e-04
# Epoch 74/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7745 - loss: 0.6031 - val_accuracy: 0.7422 - val_loss: 0.7244 - learning_rate: 1.0000e-04
# Epoch 75/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7795 - loss: 0.5903 - val_accuracy: 0.7462 - val_loss: 0.7147 - learning_rate: 1.0000e-04
# Epoch 76/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7705 - loss: 0.6012 - val_accuracy: 0.7494 - val_loss: 0.7184 - learning_rate: 1.0000e-04
# Epoch 77/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7748 - loss: 0.5965 - val_accuracy: 0.7454 - val_loss: 0.7221 - learning_rate: 1.0000e-04
# Epoch 78/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7654 - loss: 0.6177 - val_accuracy: 0.7438 - val_loss: 0.7163 - learning_rate: 1.0000e-04
# Epoch 79/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7798 - loss: 0.5915 - val_accuracy: 0.7454 - val_loss: 0.7170 - learning_rate: 1.0000e-04
# Epoch 80/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7799 - loss: 0.5888 - val_accuracy: 0.7446 - val_loss: 0.7177 - learning_rate: 1.0000e-04
# Epoch 81/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7788 - loss: 0.5914 - val_accuracy: 0.7462 - val_loss: 0.7197 - learning_rate: 1.0000e-04
# Epoch 82/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7708 - loss: 0.6041 - val_accuracy: 0.7478 - val_loss: 0.7174 - learning_rate: 1.0000e-04
# Epoch 83/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7746 - loss: 0.6004 - val_accuracy: 0.7470 - val_loss: 0.7206 - learning_rate: 1.0000e-04
# Epoch 84/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7767 - loss: 0.5964 - val_accuracy: 0.7438 - val_loss: 0.7234 - learning_rate: 1.0000e-04
# Epoch 85/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7795 - loss: 0.5949 - val_accuracy: 0.7422 - val_loss: 0.7212 - learning_rate: 1.0000e-04
# Epoch 86/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7753 - loss: 0.5955 - val_accuracy: 0.7462 - val_loss: 0.7182 - learning_rate: 1.0000e-04
# Epoch 87/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7779 - loss: 0.5832 - val_accuracy: 0.7422 - val_loss: 0.7219 - learning_rate: 1.0000e-04
# Epoch 88/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7720 - loss: 0.6068 - val_accuracy: 0.7446 - val_loss: 0.7194 - learning_rate: 1.0000e-04
# Epoch 89/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7727 - loss: 0.5925 - val_accuracy: 0.7470 - val_loss: 0.7200 - learning_rate: 1.0000e-04
# Epoch 90/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7804 - loss: 0.5809 - val_accuracy: 0.7406 - val_loss: 0.7266 - learning_rate: 1.0000e-04
# Epoch 91/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7776 - loss: 0.5941 - val_accuracy: 0.7422 - val_loss: 0.7189 - learning_rate: 1.0000e-04
# Epoch 92/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7931 - loss: 0.5583 - val_accuracy: 0.7470 - val_loss: 0.7144 - learning_rate: 1.0000e-04
# Epoch 93/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7708 - loss: 0.5975 - val_accuracy: 0.7438 - val_loss: 0.7171 - learning_rate: 1.0000e-04
# Epoch 94/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7726 - loss: 0.5921 - val_accuracy: 0.7462 - val_loss: 0.7170 - learning_rate: 1.0000e-04
# Epoch 95/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 22s 64ms/step - accuracy: 0.7818 - loss: 0.5842 - val_accuracy: 0.7470 - val_loss: 0.7142 - learning_rate: 1.0000e-04
# Epoch 96/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7757 - loss: 0.5944 - val_accuracy: 0.7470 - val_loss: 0.7218 - learning_rate: 1.0000e-04
# Epoch 97/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7771 - loss: 0.5852 - val_accuracy: 0.7422 - val_loss: 0.7236 - learning_rate: 1.0000e-04
# Epoch 98/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - accuracy: 0.7738 - loss: 0.5968 - val_accuracy: 0.7446 - val_loss: 0.7221 - learning_rate: 1.0000e-04
# Epoch 99/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7669 - loss: 0.6031 - val_accuracy: 0.7454 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 100/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.7775 - loss: 0.5943 - val_accuracy: 0.7462 - val_loss: 0.7182 - learning_rate: 1.0000e-04
# Epoch 101/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 51ms/step - accuracy: 0.7771 - loss: 0.5937 - val_accuracy: 0.7454 - val_loss: 0.7201 - learning_rate: 1.0000e-04
# Epoch 102/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - accuracy: 0.7828 - loss: 0.5858 - val_accuracy: 0.7430 - val_loss: 0.7212 - learning_rate: 1.0000e-04
# Epoch 103/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.7748 - loss: 0.5915 - val_accuracy: 0.7462 - val_loss: 0.7235 - learning_rate: 1.0000e-04
# Epoch 104/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.7871 - loss: 0.5757 - val_accuracy: 0.7430 - val_loss: 0.7211 - learning_rate: 1.0000e-04
# Epoch 105/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 53ms/step - accuracy: 0.7821 - loss: 0.5706 - val_accuracy: 0.7462 - val_loss: 0.7205 - learning_rate: 1.0000e-04
# Epoch 106/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 50ms/step - accuracy: 0.7815 - loss: 0.5860 - val_accuracy: 0.7446 - val_loss: 0.7197 - learning_rate: 1.0000e-04
# Epoch 107/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7795 - loss: 0.5770 - val_accuracy: 0.7454 - val_loss: 0.7179 - learning_rate: 1.0000e-04
# Epoch 108/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 50ms/step - accuracy: 0.7784 - loss: 0.5895 - val_accuracy: 0.7446 - val_loss: 0.7229 - learning_rate: 1.0000e-04
# Epoch 109/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7859 - loss: 0.5717 - val_accuracy: 0.7486 - val_loss: 0.7211 - learning_rate: 1.0000e-04
# Epoch 110/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7817 - loss: 0.5761 - val_accuracy: 0.7494 - val_loss: 0.7161 - learning_rate: 1.0000e-04
# Epoch 111/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7753 - loss: 0.5913 - val_accuracy: 0.7470 - val_loss: 0.7232 - learning_rate: 1.0000e-04
# Epoch 112/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.7881 - loss: 0.5707 - val_accuracy: 0.7534 - val_loss: 0.7198 - learning_rate: 1.0000e-04
# Epoch 113/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 50ms/step - accuracy: 0.7850 - loss: 0.5680 - val_accuracy: 0.7486 - val_loss: 0.7196 - learning_rate: 1.0000e-04
# Epoch 114/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 48ms/step - accuracy: 0.7875 - loss: 0.5684 - val_accuracy: 0.7438 - val_loss: 0.7202 - learning_rate: 1.0000e-04
# Epoch 115/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 50ms/step - accuracy: 0.7871 - loss: 0.5698 - val_accuracy: 0.7486 - val_loss: 0.7258 - learning_rate: 1.0000e-04
# Epoch 115: early stopping
# Restoring model weights from the end of the best epoch: 95.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.7596 - loss: 0.6650
# Test accuracy: 0.7589199542999268

# %%
# Plot training & validation accuracy values
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from keras.applications import EfficientNetB7 # Choose the desired EfficientNet variant
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Define the EfficientNet model
base_model2 = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze base model layers
base_model2.trainable = False

model3 = Sequential()
model3.add(base_model1)
model3.add(GlobalAveragePooling2D())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))  # Add dropout for regularization
model3.add(Dense(num_classes, activation='softmax'))


# Compile the model
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history = model3.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model3.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/150
# 189/350 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.5772 - loss: 1.1699
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 25
#      22 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)
#      24 # Train the model using X_train and y_train_encoded
# ---> 25 history = model3.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])
#      27 # Evaluate the model using X_test and y_test_encoded
#      28 test_loss, test_acc = model3.evaluate(X_test, y_test_encoded)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/utils/traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/backend/tensorflow/trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/Library/Python/3.9/lib/python/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D

model4 = Sequential()

# Convolutional layers
model4.add(Conv2D(30, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model4.add(Conv2D(8, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(9, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(11, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(10, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(8, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(11, (3, 3), activation='relu'))
model4.add(Conv2D(30, (3, 3), activation='relu'))
model4.add(Conv2D(45, (3, 3), activation='relu'))

# Average Pooling layer
model4.add(AveragePooling2D(pool_size=(2, 2)))

# Flatten layer
model4.add(Flatten())

# Dense layers
model4.add(Dense(12, activation='relu'))

# Output layer
model4.add(Dense(5, activation='softmax'))

# Print model summary
model4.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_14 (Conv2D)              │ (None, 62, 62, 30)     │           840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 60, 60, 8)      │         2,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 58, 58, 30)     │         2,190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 56, 56, 9)      │         2,439 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 54, 54, 30)     │         2,460 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 52, 52, 11)     │         2,981 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 50, 50, 30)     │         3,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 48, 48, 10)     │         2,710 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 46, 46, 30)     │         2,730 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 44, 44, 8)      │         2,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 42, 42, 30)     │         2,190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 40, 40, 11)     │         2,981 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 38, 38, 30)     │         3,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 36, 36, 45)     │        12,195 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 18, 18, 45)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 14580)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 12)             │       174,972 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 5)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 219,089 (855.82 KB)
#  Trainable params: 219,089 (855.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model4.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history = model4.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model4.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 74s 207ms/step - accuracy: 0.5219 - loss: 1.2858 - val_accuracy: 0.6120 - val_loss: 1.1082 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 75s 214ms/step - accuracy: 0.6007 - loss: 1.0993 - val_accuracy: 0.6442 - val_loss: 1.0190 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 75s 214ms/step - accuracy: 0.6177 - loss: 1.0305 - val_accuracy: 0.6361 - val_loss: 1.0747 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 85s 242ms/step - accuracy: 0.6480 - loss: 0.9628 - val_accuracy: 0.6594 - val_loss: 0.9369 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 93s 264ms/step - accuracy: 0.6738 - loss: 0.8977 - val_accuracy: 0.6731 - val_loss: 0.9369 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 94s 270ms/step - accuracy: 0.6834 - loss: 0.8731 - val_accuracy: 0.6739 - val_loss: 0.9456 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 94s 269ms/step - accuracy: 0.6904 - loss: 0.8485 - val_accuracy: 0.6602 - val_loss: 0.9429 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 96s 274ms/step - accuracy: 0.7102 - loss: 0.7825 - val_accuracy: 0.6859 - val_loss: 0.9886 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 97s 277ms/step - accuracy: 0.7165 - loss: 0.7766 - val_accuracy: 0.6779 - val_loss: 0.9047 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 97s 277ms/step - accuracy: 0.7356 - loss: 0.7210 - val_accuracy: 0.6803 - val_loss: 0.9844 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 97s 277ms/step - accuracy: 0.7556 - loss: 0.6679 - val_accuracy: 0.6691 - val_loss: 0.9771 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 101s 289ms/step - accuracy: 0.7681 - loss: 0.6346 - val_accuracy: 0.6659 - val_loss: 0.9365 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 99s 283ms/step - accuracy: 0.7816 - loss: 0.5952 - val_accuracy: 0.6675 - val_loss: 1.0410 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 100s 285ms/step - accuracy: 0.8130 - loss: 0.5248 - val_accuracy: 0.6771 - val_loss: 1.0898 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 102s 291ms/step - accuracy: 0.8616 - loss: 0.3918 - val_accuracy: 0.6715 - val_loss: 1.2120 - learning_rate: 1.0000e-04
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 107s 305ms/step - accuracy: 0.8939 - loss: 0.3083 - val_accuracy: 0.6763 - val_loss: 1.2972 - learning_rate: 1.0000e-04
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 103s 295ms/step - accuracy: 0.9073 - loss: 0.2758 - val_accuracy: 0.6635 - val_loss: 1.4307 - learning_rate: 1.0000e-04
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 104s 296ms/step - accuracy: 0.9143 - loss: 0.2589 - val_accuracy: 0.6586 - val_loss: 1.5276 - learning_rate: 1.0000e-04
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 105s 300ms/step - accuracy: 0.9236 - loss: 0.2197 - val_accuracy: 0.6602 - val_loss: 1.6274 - learning_rate: 1.0000e-04
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 106s 303ms/step - accuracy: 0.9342 - loss: 0.2008 - val_accuracy: 0.6530 - val_loss: 1.7106 - learning_rate: 1.0000e-04
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 104s 297ms/step - accuracy: 0.9371 - loss: 0.1939 - val_accuracy: 0.6490 - val_loss: 1.8643 - learning_rate: 1.0000e-04
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 97s 277ms/step - accuracy: 0.9420 - loss: 0.1767 - val_accuracy: 0.6474 - val_loss: 2.0383 - learning_rate: 1.0000e-04
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 89s 255ms/step - accuracy: 0.9502 - loss: 0.1592 - val_accuracy: 0.6554 - val_loss: 2.1154 - learning_rate: 1.0000e-04
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 81s 231ms/step - accuracy: 0.9597 - loss: 0.1301 - val_accuracy: 0.6482 - val_loss: 2.2469 - learning_rate: 1.0000e-04
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 85s 243ms/step - accuracy: 0.9600 - loss: 0.1230 - val_accuracy: 0.6434 - val_loss: 2.5161 - learning_rate: 1.0000e-04
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 84s 240ms/step - accuracy: 0.9669 - loss: 0.1099 - val_accuracy: 0.6386 - val_loss: 2.6945 - learning_rate: 1.0000e-04
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 85s 244ms/step - accuracy: 0.9717 - loss: 0.0981 - val_accuracy: 0.6490 - val_loss: 2.9166 - learning_rate: 1.0000e-04
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 85s 243ms/step - accuracy: 0.9780 - loss: 0.0753 - val_accuracy: 0.6434 - val_loss: 3.0524 - learning_rate: 1.0000e-04
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 87s 248ms/step - accuracy: 0.9799 - loss: 0.0702 - val_accuracy: 0.6506 - val_loss: 3.2809 - learning_rate: 1.0000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 9.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.6875 - loss: 0.8935
# Test accuracy: 0.6872388124465942
