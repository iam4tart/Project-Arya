# %%
import numpy as np 
import pandas as pd
import operator
import os
import chart_studio.tools as tls

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from matplotlib.backend_bases import RendererBase
from scipy import signal
from scipy.io import wavfile

import os
import numpy as np

from PIL import Image

from scipy.fftpack import fft
import librosa
import librosa.display

import plotly as py
tls.set_credentials_file(username='iam4tart',api_key='Docq9bPOpIqBxnDmPIxJ')

import chart_studio.plotly as py
import plotly.graph_objs as go

import cufflinks as cf
import IPython.display as ipd

# %%
def get_files_with_features(path):
    data_ = []
    count = {}
    files = os.listdir(path)
    for file in files:
        labels = file.split("-")[:3]
        if len(labels) < 3:
            continue 
        data = {
            "keyword": labels[0],
            "stress": labels[2],
            "environment": labels[1],
            "path": os.path.join(path, file)
        }
        for label in labels:
            if label not in count.keys():
                count[label] = 1
            else:
                count[label] += 1

        data_.append(data)

    if data_:
        df = pd.DataFrame(data_)
    else:
        df = pd.DataFrame(columns=['keyword', 'stress', 'environment', 'path'])
    return data_, count, df

# Example usage
path = '/Users/pabitraghosh/convertaudio/AudioToSpectogram/spectrograms'
dataset_with_features, count, df_with_features = get_files_with_features(path)
print(df_with_features.head())
# Out:
#       keyword stress environment  \
# 0          go   calm        safe
# 1        help   calm        safe
# 2  background   calm        safe
# 3  background   calm        safe
# 4         yes  happy        safe
#
#                                                 path
# 0  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 1  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 2  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 3  /Users/pabitraghosh/convertaudio/AudioToSpecto...
# 4  /Users/pabitraghosh/convertaudio/AudioToSpecto...

# %%
df_with_features.count()
# Out:
# keyword        15555
# stress         15555
# environment    15555
# path           15555
# dtype: int64

# %%
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
images = []
labels = []

for index, row in df_with_features.iterrows():
    image = cv2.imread(row['path'])
    image = cv2.resize(image, (64, 64))  # Resize images to a common size
    images.append(image)
    labels.append(row['stress'])

images = np.array(images)
labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming y_train and y_test are your label arrays

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Fit and transform the training labels (y_train)
y_train_encoded = label_encoder.fit_transform(y_train)

# Transform the test labels (y_test) using the fitted encoder
y_test_encoded = label_encoder.transform(y_test)

# %%
num_classes = df_with_features['stress'].nunique()
print(num_classes)
# Out:
# 5

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.5447 - loss: 5.1425 - val_accuracy: 0.6530 - val_loss: 1.0083 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6580 - loss: 0.9408 - val_accuracy: 0.6418 - val_loss: 0.9897 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6916 - loss: 0.8472 - val_accuracy: 0.6747 - val_loss: 0.9196 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.7201 - loss: 0.7618 - val_accuracy: 0.6948 - val_loss: 0.9224 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7504 - loss: 0.6769 - val_accuracy: 0.6956 - val_loss: 0.9556 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7854 - loss: 0.5949 - val_accuracy: 0.7084 - val_loss: 1.0321 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.8142 - loss: 0.5204 - val_accuracy: 0.7165 - val_loss: 0.9948 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.8406 - loss: 0.4517 - val_accuracy: 0.7036 - val_loss: 1.0700 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.8777 - loss: 0.3696 - val_accuracy: 0.7253 - val_loss: 1.0661 - learning_rate: 1.0000e-04
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.8911 - loss: 0.3185 - val_accuracy: 0.7293 - val_loss: 1.0987 - learning_rate: 1.0000e-04
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.8900 - loss: 0.3127 - val_accuracy: 0.7357 - val_loss: 1.1298 - learning_rate: 1.0000e-04
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9015 - loss: 0.2880 - val_accuracy: 0.7373 - val_loss: 1.1554 - learning_rate: 1.0000e-04
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.9020 - loss: 0.2828 - val_accuracy: 0.7349 - val_loss: 1.1892 - learning_rate: 1.0000e-04
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9091 - loss: 0.2665 - val_accuracy: 0.7261 - val_loss: 1.2377 - learning_rate: 1.0000e-04
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9146 - loss: 0.2504 - val_accuracy: 0.7365 - val_loss: 1.2477 - learning_rate: 1.0000e-04
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.9185 - loss: 0.2424 - val_accuracy: 0.7309 - val_loss: 1.3195 - learning_rate: 1.0000e-04
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9216 - loss: 0.2350 - val_accuracy: 0.7341 - val_loss: 1.3034 - learning_rate: 1.0000e-04
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9224 - loss: 0.2251 - val_accuracy: 0.7422 - val_loss: 1.3415 - learning_rate: 1.0000e-04
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9242 - loss: 0.2107 - val_accuracy: 0.7341 - val_loss: 1.3893 - learning_rate: 1.0000e-04
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9289 - loss: 0.1971 - val_accuracy: 0.7422 - val_loss: 1.4004 - learning_rate: 1.0000e-04
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.9308 - loss: 0.2001 - val_accuracy: 0.7382 - val_loss: 1.4831 - learning_rate: 1.0000e-04
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9345 - loss: 0.1862 - val_accuracy: 0.7398 - val_loss: 1.4998 - learning_rate: 1.0000e-04
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.9373 - loss: 0.1706 - val_accuracy: 0.7349 - val_loss: 1.5549 - learning_rate: 1.0000e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6590 - loss: 0.9403
# Test accuracy: 0.6657023429870605

# %%
from keras.applications import ResNet50
from keras.layers import GlobalAveragePooling2D, Dropout

# Load pre-trained ResNet50 model (excluding the top layer)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze the base model layers
base_model.trainable = False

# Add custom layers on top of the base model
model1 = Sequential()
model1.add(base_model)
model1.add(GlobalAveragePooling2D())
model1.add(Dense(256, activation='relu'))
model1.add(Dropout(0.5))  # Add dropout for regularization
model1.add(Dense(num_classes, activation='softmax'))  # Assuming num_classes = 5

# Compile the model
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history = model1.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model1.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 49s 1us/step
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 36s 98ms/step - accuracy: 0.6074 - loss: 1.2141 - val_accuracy: 0.7060 - val_loss: 0.7926 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 111ms/step - accuracy: 0.6826 - loss: 0.8601 - val_accuracy: 0.7317 - val_loss: 0.7354 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.7054 - loss: 0.7830 - val_accuracy: 0.7365 - val_loss: 0.7165 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 37s 106ms/step - accuracy: 0.7197 - loss: 0.7487 - val_accuracy: 0.7486 - val_loss: 0.7077 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 40s 114ms/step - accuracy: 0.7340 - loss: 0.7246 - val_accuracy: 0.7373 - val_loss: 0.6913 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 36s 104ms/step - accuracy: 0.7506 - loss: 0.6702 - val_accuracy: 0.7430 - val_loss: 0.6867 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 37s 105ms/step - accuracy: 0.7425 - loss: 0.6869 - val_accuracy: 0.7518 - val_loss: 0.6902 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 107ms/step - accuracy: 0.7517 - loss: 0.6553 - val_accuracy: 0.7502 - val_loss: 0.6892 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.7549 - loss: 0.6430 - val_accuracy: 0.7502 - val_loss: 0.6890 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 111ms/step - accuracy: 0.7564 - loss: 0.6268 - val_accuracy: 0.7566 - val_loss: 0.6800 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 40s 113ms/step - accuracy: 0.7766 - loss: 0.5863 - val_accuracy: 0.7598 - val_loss: 0.6650 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 38s 110ms/step - accuracy: 0.7735 - loss: 0.5974 - val_accuracy: 0.7631 - val_loss: 0.6812 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 39s 111ms/step - accuracy: 0.7864 - loss: 0.5606 - val_accuracy: 0.7663 - val_loss: 0.6641 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.7845 - loss: 0.5593 - val_accuracy: 0.7622 - val_loss: 0.6606 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.7884 - loss: 0.5463 - val_accuracy: 0.7775 - val_loss: 0.6475 - learning_rate: 0.0010
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.7949 - loss: 0.5396 - val_accuracy: 0.7687 - val_loss: 0.6611 - learning_rate: 0.0010
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.8033 - loss: 0.4999 - val_accuracy: 0.7614 - val_loss: 0.6607 - learning_rate: 0.0010
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 119ms/step - accuracy: 0.8119 - loss: 0.4961 - val_accuracy: 0.7671 - val_loss: 0.6615 - learning_rate: 0.0010
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 43s 122ms/step - accuracy: 0.8010 - loss: 0.5048 - val_accuracy: 0.7614 - val_loss: 0.6818 - learning_rate: 0.0010
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.8133 - loss: 0.4919 - val_accuracy: 0.7751 - val_loss: 0.6741 - learning_rate: 0.0010
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.8364 - loss: 0.4230 - val_accuracy: 0.7735 - val_loss: 0.6663 - learning_rate: 1.0000e-04
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 43s 122ms/step - accuracy: 0.8570 - loss: 0.3718 - val_accuracy: 0.7799 - val_loss: 0.6671 - learning_rate: 1.0000e-04
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.8450 - loss: 0.3866 - val_accuracy: 0.7743 - val_loss: 0.6816 - learning_rate: 1.0000e-04
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 43s 122ms/step - accuracy: 0.8577 - loss: 0.3684 - val_accuracy: 0.7719 - val_loss: 0.6719 - learning_rate: 1.0000e-04
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.8558 - loss: 0.3632 - val_accuracy: 0.7775 - val_loss: 0.6768 - learning_rate: 1.0000e-04
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 44s 124ms/step - accuracy: 0.8626 - loss: 0.3536 - val_accuracy: 0.7751 - val_loss: 0.6732 - learning_rate: 1.0000e-04
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 44s 125ms/step - accuracy: 0.8667 - loss: 0.3395 - val_accuracy: 0.7799 - val_loss: 0.6901 - learning_rate: 1.0000e-04
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 43s 123ms/step - accuracy: 0.8624 - loss: 0.3580 - val_accuracy: 0.7767 - val_loss: 0.6893 - learning_rate: 1.0000e-04
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.8712 - loss: 0.3331 - val_accuracy: 0.7799 - val_loss: 0.6867 - learning_rate: 1.0000e-04
# Epoch 30/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.8663 - loss: 0.3430 - val_accuracy: 0.7807 - val_loss: 0.6973 - learning_rate: 1.0000e-04
# Epoch 31/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.8739 - loss: 0.3269 - val_accuracy: 0.7767 - val_loss: 0.6847 - learning_rate: 1.0000e-04
# Epoch 32/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 43s 122ms/step - accuracy: 0.8719 - loss: 0.3239 - val_accuracy: 0.7799 - val_loss: 0.6962 - learning_rate: 1.0000e-04
# Epoch 33/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 45s 127ms/step - accuracy: 0.8783 - loss: 0.3287 - val_accuracy: 0.7839 - val_loss: 0.6978 - learning_rate: 1.0000e-04
# Epoch 34/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 44s 125ms/step - accuracy: 0.8755 - loss: 0.3136 - val_accuracy: 0.7799 - val_loss: 0.7066 - learning_rate: 1.0000e-04
# Epoch 35/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 46s 132ms/step - accuracy: 0.8772 - loss: 0.3003 - val_accuracy: 0.7807 - val_loss: 0.7014 - learning_rate: 1.0000e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 112ms/step - accuracy: 0.7676 - loss: 0.6318
# Test accuracy: 0.7704917788505554

# %%
from keras.applications import EfficientNetB0 # Choose the desired EfficientNet variant
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Define the EfficientNet model
base_model1 = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze base model layers
base_model1.trainable = False

model2 = Sequential()
model2.add(base_model1)
model2.add(GlobalAveragePooling2D())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.5))  # Add dropout for regularization
model2.add(Dense(num_classes, activation='softmax'))


# Compile the model
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history = model2.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model2.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.5961 - loss: 1.1028 - val_accuracy: 0.6787 - val_loss: 0.9058 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6485 - loss: 0.9475 - val_accuracy: 0.6972 - val_loss: 0.8510 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.6631 - loss: 0.9252 - val_accuracy: 0.7060 - val_loss: 0.8287 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.6812 - loss: 0.8809 - val_accuracy: 0.7004 - val_loss: 0.8429 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6761 - loss: 0.8782 - val_accuracy: 0.7068 - val_loss: 0.8161 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.6832 - loss: 0.8531 - val_accuracy: 0.7213 - val_loss: 0.7938 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.6988 - loss: 0.8316 - val_accuracy: 0.7141 - val_loss: 0.7901 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.6976 - loss: 0.8295 - val_accuracy: 0.7060 - val_loss: 0.8135 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6978 - loss: 0.8177 - val_accuracy: 0.7157 - val_loss: 0.7803 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6972 - loss: 0.8162 - val_accuracy: 0.7261 - val_loss: 0.7835 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.7076 - loss: 0.7865 - val_accuracy: 0.7092 - val_loss: 0.7898 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7084 - loss: 0.8005 - val_accuracy: 0.7189 - val_loss: 0.7814 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.7131 - loss: 0.7821 - val_accuracy: 0.7293 - val_loss: 0.7743 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7089 - loss: 0.7844 - val_accuracy: 0.7277 - val_loss: 0.7723 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7194 - loss: 0.7667 - val_accuracy: 0.7293 - val_loss: 0.7714 - learning_rate: 0.0010
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7101 - loss: 0.7689 - val_accuracy: 0.7213 - val_loss: 0.7659 - learning_rate: 0.0010
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7083 - loss: 0.7731 - val_accuracy: 0.7181 - val_loss: 0.7733 - learning_rate: 0.0010
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7135 - loss: 0.7544 - val_accuracy: 0.7325 - val_loss: 0.7646 - learning_rate: 0.0010
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7172 - loss: 0.7646 - val_accuracy: 0.7213 - val_loss: 0.7731 - learning_rate: 0.0010
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7328 - loss: 0.7279 - val_accuracy: 0.7309 - val_loss: 0.7628 - learning_rate: 0.0010
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7265 - loss: 0.7285 - val_accuracy: 0.7325 - val_loss: 0.7533 - learning_rate: 0.0010
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7186 - loss: 0.7460 - val_accuracy: 0.7309 - val_loss: 0.7573 - learning_rate: 0.0010
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7235 - loss: 0.7363 - val_accuracy: 0.7301 - val_loss: 0.7637 - learning_rate: 0.0010
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7315 - loss: 0.7159 - val_accuracy: 0.7285 - val_loss: 0.7448 - learning_rate: 0.0010
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7334 - loss: 0.7216 - val_accuracy: 0.7365 - val_loss: 0.7600 - learning_rate: 0.0010
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7262 - loss: 0.7382 - val_accuracy: 0.7373 - val_loss: 0.7537 - learning_rate: 0.0010
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7271 - loss: 0.7255 - val_accuracy: 0.7341 - val_loss: 0.7423 - learning_rate: 0.0010
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7237 - loss: 0.7174 - val_accuracy: 0.7293 - val_loss: 0.7382 - learning_rate: 0.0010
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7366 - loss: 0.6989 - val_accuracy: 0.7430 - val_loss: 0.7350 - learning_rate: 0.0010
# Epoch 30/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7278 - loss: 0.7117 - val_accuracy: 0.7390 - val_loss: 0.7410 - learning_rate: 0.0010
# Epoch 31/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7333 - loss: 0.7091 - val_accuracy: 0.7221 - val_loss: 0.7582 - learning_rate: 0.0010
# Epoch 32/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7400 - loss: 0.7000 - val_accuracy: 0.7309 - val_loss: 0.7628 - learning_rate: 0.0010
# Epoch 33/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7343 - loss: 0.7177 - val_accuracy: 0.7373 - val_loss: 0.7495 - learning_rate: 0.0010
# Epoch 34/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7336 - loss: 0.6990 - val_accuracy: 0.7373 - val_loss: 0.7625 - learning_rate: 0.0010
# Epoch 35/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7443 - loss: 0.6802 - val_accuracy: 0.7446 - val_loss: 0.7416 - learning_rate: 1.0000e-04
# Epoch 36/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7528 - loss: 0.6522 - val_accuracy: 0.7430 - val_loss: 0.7390 - learning_rate: 1.0000e-04
# Epoch 37/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7562 - loss: 0.6455 - val_accuracy: 0.7454 - val_loss: 0.7331 - learning_rate: 1.0000e-04
# Epoch 38/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7666 - loss: 0.6391 - val_accuracy: 0.7462 - val_loss: 0.7330 - learning_rate: 1.0000e-04
# Epoch 39/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7603 - loss: 0.6345 - val_accuracy: 0.7486 - val_loss: 0.7293 - learning_rate: 1.0000e-04
# Epoch 40/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7692 - loss: 0.6170 - val_accuracy: 0.7486 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 41/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7724 - loss: 0.6095 - val_accuracy: 0.7478 - val_loss: 0.7337 - learning_rate: 1.0000e-04
# Epoch 42/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7615 - loss: 0.6271 - val_accuracy: 0.7470 - val_loss: 0.7331 - learning_rate: 1.0000e-04
# Epoch 43/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7629 - loss: 0.6188 - val_accuracy: 0.7478 - val_loss: 0.7318 - learning_rate: 1.0000e-04
# Epoch 44/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7672 - loss: 0.6261 - val_accuracy: 0.7494 - val_loss: 0.7275 - learning_rate: 1.0000e-04
# Epoch 45/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7641 - loss: 0.6302 - val_accuracy: 0.7462 - val_loss: 0.7286 - learning_rate: 1.0000e-04
# Epoch 46/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7535 - loss: 0.6385 - val_accuracy: 0.7494 - val_loss: 0.7284 - learning_rate: 1.0000e-04
# Epoch 47/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7712 - loss: 0.6165 - val_accuracy: 0.7494 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 48/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.7698 - loss: 0.6231 - val_accuracy: 0.7518 - val_loss: 0.7287 - learning_rate: 1.0000e-04
# Epoch 49/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7711 - loss: 0.6180 - val_accuracy: 0.7502 - val_loss: 0.7272 - learning_rate: 1.0000e-04
# Epoch 50/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7749 - loss: 0.6032 - val_accuracy: 0.7446 - val_loss: 0.7310 - learning_rate: 1.0000e-04
# Epoch 51/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7648 - loss: 0.6207 - val_accuracy: 0.7422 - val_loss: 0.7310 - learning_rate: 1.0000e-04
# Epoch 52/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7679 - loss: 0.6257 - val_accuracy: 0.7502 - val_loss: 0.7256 - learning_rate: 1.0000e-04
# Epoch 53/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7655 - loss: 0.6039 - val_accuracy: 0.7422 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 54/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7709 - loss: 0.6199 - val_accuracy: 0.7486 - val_loss: 0.7294 - learning_rate: 1.0000e-04
# Epoch 55/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7750 - loss: 0.6063 - val_accuracy: 0.7494 - val_loss: 0.7258 - learning_rate: 1.0000e-04
# Epoch 56/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7674 - loss: 0.6088 - val_accuracy: 0.7478 - val_loss: 0.7303 - learning_rate: 1.0000e-04
# Epoch 57/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7755 - loss: 0.5970 - val_accuracy: 0.7470 - val_loss: 0.7303 - learning_rate: 1.0000e-04
# Epoch 58/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7713 - loss: 0.5999 - val_accuracy: 0.7478 - val_loss: 0.7276 - learning_rate: 1.0000e-04
# Epoch 59/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7737 - loss: 0.6084 - val_accuracy: 0.7510 - val_loss: 0.7295 - learning_rate: 1.0000e-04
# Epoch 60/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7624 - loss: 0.6128 - val_accuracy: 0.7510 - val_loss: 0.7252 - learning_rate: 1.0000e-04
# Epoch 61/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7722 - loss: 0.6012 - val_accuracy: 0.7534 - val_loss: 0.7314 - learning_rate: 1.0000e-04
# Epoch 62/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7727 - loss: 0.6015 - val_accuracy: 0.7526 - val_loss: 0.7296 - learning_rate: 1.0000e-04
# Epoch 63/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7712 - loss: 0.6135 - val_accuracy: 0.7454 - val_loss: 0.7277 - learning_rate: 1.0000e-04
# Epoch 64/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7767 - loss: 0.5882 - val_accuracy: 0.7478 - val_loss: 0.7280 - learning_rate: 1.0000e-04
# Epoch 65/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7790 - loss: 0.5946 - val_accuracy: 0.7510 - val_loss: 0.7311 - learning_rate: 1.0000e-04
# Epoch 66/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7773 - loss: 0.5958 - val_accuracy: 0.7518 - val_loss: 0.7304 - learning_rate: 1.0000e-04
# Epoch 67/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7740 - loss: 0.6043 - val_accuracy: 0.7510 - val_loss: 0.7255 - learning_rate: 1.0000e-04
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 47.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7527 - loss: 0.6732
# Test accuracy: 0.7560269832611084

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from keras.applications import EfficientNetB7 # Choose the desired EfficientNet variant
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Define the EfficientNet model
base_model2 = EfficientNetB7(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze base model layers
base_model2.trainable = False

model3 = Sequential()
model3.add(base_model1)
model3.add(GlobalAveragePooling2D())
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.5))  # Add dropout for regularization
model3.add(Dense(num_classes, activation='softmax'))


# Compile the model
model3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Assuming X_train, X_test, y_train_encoded, y_test_encoded are already prepared

# Define the callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=0.0001)

# Train the model using X_train and y_train_encoded
history = model3.fit(X_train, y_train_encoded, epochs=150, batch_size=32, validation_split=0.1, callbacks=[early_stopping, reduce_lr])

# Evaluate the model using X_test and y_test_encoded
test_loss, test_acc = model3.evaluate(X_test, y_test_encoded)
print(f'Test accuracy: {test_acc}')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 117s 0us/step
# Epoch 1/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.5958 - loss: 1.1106 - val_accuracy: 0.6747 - val_loss: 0.9069 - learning_rate: 0.0010
# Epoch 2/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.6548 - loss: 0.9445 - val_accuracy: 0.6892 - val_loss: 0.8607 - learning_rate: 0.0010
# Epoch 3/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.6663 - loss: 0.9109 - val_accuracy: 0.7060 - val_loss: 0.8349 - learning_rate: 0.0010
# Epoch 4/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6692 - loss: 0.8909 - val_accuracy: 0.7092 - val_loss: 0.8239 - learning_rate: 0.0010
# Epoch 5/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.6866 - loss: 0.8689 - val_accuracy: 0.7012 - val_loss: 0.8176 - learning_rate: 0.0010
# Epoch 6/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6957 - loss: 0.8410 - val_accuracy: 0.6988 - val_loss: 0.8127 - learning_rate: 0.0010
# Epoch 7/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.6970 - loss: 0.8314 - val_accuracy: 0.7181 - val_loss: 0.7905 - learning_rate: 0.0010
# Epoch 8/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.6947 - loss: 0.8193 - val_accuracy: 0.7108 - val_loss: 0.8046 - learning_rate: 0.0010
# Epoch 9/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.6922 - loss: 0.8348 - val_accuracy: 0.7189 - val_loss: 0.7948 - learning_rate: 0.0010
# Epoch 10/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.6935 - loss: 0.8273 - val_accuracy: 0.7060 - val_loss: 0.7838 - learning_rate: 0.0010
# Epoch 11/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7050 - loss: 0.7978 - val_accuracy: 0.7213 - val_loss: 0.7764 - learning_rate: 0.0010
# Epoch 12/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7096 - loss: 0.7936 - val_accuracy: 0.7141 - val_loss: 0.7831 - learning_rate: 0.0010
# Epoch 13/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7038 - loss: 0.8012 - val_accuracy: 0.7181 - val_loss: 0.7618 - learning_rate: 0.0010
# Epoch 14/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7088 - loss: 0.7845 - val_accuracy: 0.7237 - val_loss: 0.7661 - learning_rate: 0.0010
# Epoch 15/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7189 - loss: 0.7617 - val_accuracy: 0.7269 - val_loss: 0.7815 - learning_rate: 0.0010
# Epoch 16/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7132 - loss: 0.7695 - val_accuracy: 0.7317 - val_loss: 0.7644 - learning_rate: 0.0010
# Epoch 17/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7160 - loss: 0.7675 - val_accuracy: 0.7269 - val_loss: 0.7624 - learning_rate: 0.0010
# Epoch 18/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7239 - loss: 0.7486 - val_accuracy: 0.7349 - val_loss: 0.7645 - learning_rate: 0.0010
# Epoch 19/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7320 - loss: 0.7216 - val_accuracy: 0.7373 - val_loss: 0.7480 - learning_rate: 1.0000e-04
# Epoch 20/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7419 - loss: 0.6952 - val_accuracy: 0.7414 - val_loss: 0.7460 - learning_rate: 1.0000e-04
# Epoch 21/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7437 - loss: 0.7022 - val_accuracy: 0.7430 - val_loss: 0.7458 - learning_rate: 1.0000e-04
# Epoch 22/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7398 - loss: 0.6955 - val_accuracy: 0.7390 - val_loss: 0.7450 - learning_rate: 1.0000e-04
# Epoch 23/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.7341 - loss: 0.6942 - val_accuracy: 0.7349 - val_loss: 0.7406 - learning_rate: 1.0000e-04
# Epoch 24/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7458 - loss: 0.6859 - val_accuracy: 0.7398 - val_loss: 0.7436 - learning_rate: 1.0000e-04
# Epoch 25/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7488 - loss: 0.6738 - val_accuracy: 0.7414 - val_loss: 0.7438 - learning_rate: 1.0000e-04
# Epoch 26/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7414 - loss: 0.6891 - val_accuracy: 0.7373 - val_loss: 0.7398 - learning_rate: 1.0000e-04
# Epoch 27/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7430 - loss: 0.6914 - val_accuracy: 0.7422 - val_loss: 0.7418 - learning_rate: 1.0000e-04
# Epoch 28/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7379 - loss: 0.6892 - val_accuracy: 0.7438 - val_loss: 0.7381 - learning_rate: 1.0000e-04
# Epoch 29/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7481 - loss: 0.6712 - val_accuracy: 0.7373 - val_loss: 0.7425 - learning_rate: 1.0000e-04
# Epoch 30/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7475 - loss: 0.6838 - val_accuracy: 0.7430 - val_loss: 0.7393 - learning_rate: 1.0000e-04
# Epoch 31/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7510 - loss: 0.6730 - val_accuracy: 0.7422 - val_loss: 0.7390 - learning_rate: 1.0000e-04
# Epoch 32/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7559 - loss: 0.6697 - val_accuracy: 0.7341 - val_loss: 0.7380 - learning_rate: 1.0000e-04
# Epoch 33/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7510 - loss: 0.6640 - val_accuracy: 0.7406 - val_loss: 0.7378 - learning_rate: 1.0000e-04
# Epoch 34/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7528 - loss: 0.6731 - val_accuracy: 0.7390 - val_loss: 0.7363 - learning_rate: 1.0000e-04
# Epoch 35/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.7523 - loss: 0.6574 - val_accuracy: 0.7414 - val_loss: 0.7352 - learning_rate: 1.0000e-04
# Epoch 36/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7556 - loss: 0.6668 - val_accuracy: 0.7414 - val_loss: 0.7389 - learning_rate: 1.0000e-04
# Epoch 37/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7477 - loss: 0.6784 - val_accuracy: 0.7446 - val_loss: 0.7374 - learning_rate: 1.0000e-04
# Epoch 38/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7542 - loss: 0.6637 - val_accuracy: 0.7414 - val_loss: 0.7325 - learning_rate: 1.0000e-04
# Epoch 39/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7520 - loss: 0.6585 - val_accuracy: 0.7414 - val_loss: 0.7355 - learning_rate: 1.0000e-04
# Epoch 40/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7420 - loss: 0.6752 - val_accuracy: 0.7382 - val_loss: 0.7359 - learning_rate: 1.0000e-04
# Epoch 41/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7412 - loss: 0.6680 - val_accuracy: 0.7390 - val_loss: 0.7398 - learning_rate: 1.0000e-04
# Epoch 42/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7544 - loss: 0.6561 - val_accuracy: 0.7422 - val_loss: 0.7353 - learning_rate: 1.0000e-04
# Epoch 43/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7513 - loss: 0.6548 - val_accuracy: 0.7438 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 44/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7538 - loss: 0.6563 - val_accuracy: 0.7414 - val_loss: 0.7361 - learning_rate: 1.0000e-04
# Epoch 45/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7548 - loss: 0.6528 - val_accuracy: 0.7365 - val_loss: 0.7381 - learning_rate: 1.0000e-04
# Epoch 46/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7577 - loss: 0.6447 - val_accuracy: 0.7382 - val_loss: 0.7366 - learning_rate: 1.0000e-04
# Epoch 47/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7505 - loss: 0.6673 - val_accuracy: 0.7462 - val_loss: 0.7343 - learning_rate: 1.0000e-04
# Epoch 48/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7544 - loss: 0.6563 - val_accuracy: 0.7406 - val_loss: 0.7355 - learning_rate: 1.0000e-04
# Epoch 49/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7541 - loss: 0.6535 - val_accuracy: 0.7430 - val_loss: 0.7368 - learning_rate: 1.0000e-04
# Epoch 50/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7516 - loss: 0.6581 - val_accuracy: 0.7430 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 51/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7632 - loss: 0.6373 - val_accuracy: 0.7373 - val_loss: 0.7398 - learning_rate: 1.0000e-04
# Epoch 52/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7663 - loss: 0.6373 - val_accuracy: 0.7430 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 53/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7557 - loss: 0.6465 - val_accuracy: 0.7454 - val_loss: 0.7322 - learning_rate: 1.0000e-04
# Epoch 54/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7598 - loss: 0.6372 - val_accuracy: 0.7470 - val_loss: 0.7364 - learning_rate: 1.0000e-04
# Epoch 55/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7660 - loss: 0.6395 - val_accuracy: 0.7438 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 56/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7635 - loss: 0.6433 - val_accuracy: 0.7446 - val_loss: 0.7319 - learning_rate: 1.0000e-04
# Epoch 57/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.7679 - loss: 0.6387 - val_accuracy: 0.7446 - val_loss: 0.7327 - learning_rate: 1.0000e-04
# Epoch 58/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7587 - loss: 0.6331 - val_accuracy: 0.7446 - val_loss: 0.7353 - learning_rate: 1.0000e-04
# Epoch 59/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7554 - loss: 0.6440 - val_accuracy: 0.7422 - val_loss: 0.7290 - learning_rate: 1.0000e-04
# Epoch 60/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7566 - loss: 0.6452 - val_accuracy: 0.7382 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 61/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.7674 - loss: 0.6322 - val_accuracy: 0.7446 - val_loss: 0.7351 - learning_rate: 1.0000e-04
# Epoch 62/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7549 - loss: 0.6407 - val_accuracy: 0.7470 - val_loss: 0.7342 - learning_rate: 1.0000e-04
# Epoch 63/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7609 - loss: 0.6379 - val_accuracy: 0.7486 - val_loss: 0.7315 - learning_rate: 1.0000e-04
# Epoch 64/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7589 - loss: 0.6393 - val_accuracy: 0.7430 - val_loss: 0.7319 - learning_rate: 1.0000e-04
# Epoch 65/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7651 - loss: 0.6230 - val_accuracy: 0.7446 - val_loss: 0.7311 - learning_rate: 1.0000e-04
# Epoch 66/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7651 - loss: 0.6413 - val_accuracy: 0.7494 - val_loss: 0.7327 - learning_rate: 1.0000e-04
# Epoch 67/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7581 - loss: 0.6343 - val_accuracy: 0.7446 - val_loss: 0.7318 - learning_rate: 1.0000e-04
# Epoch 68/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7606 - loss: 0.6326 - val_accuracy: 0.7430 - val_loss: 0.7309 - learning_rate: 1.0000e-04
# Epoch 69/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 40ms/step - accuracy: 0.7656 - loss: 0.6285 - val_accuracy: 0.7446 - val_loss: 0.7300 - learning_rate: 1.0000e-04
# Epoch 70/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7669 - loss: 0.6224 - val_accuracy: 0.7446 - val_loss: 0.7272 - learning_rate: 1.0000e-04
# Epoch 71/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7625 - loss: 0.6238 - val_accuracy: 0.7373 - val_loss: 0.7276 - learning_rate: 1.0000e-04
# Epoch 72/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7709 - loss: 0.6299 - val_accuracy: 0.7373 - val_loss: 0.7295 - learning_rate: 1.0000e-04
# Epoch 73/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7651 - loss: 0.6253 - val_accuracy: 0.7454 - val_loss: 0.7306 - learning_rate: 1.0000e-04
# Epoch 74/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7702 - loss: 0.6149 - val_accuracy: 0.7438 - val_loss: 0.7286 - learning_rate: 1.0000e-04
# Epoch 75/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7660 - loss: 0.6245 - val_accuracy: 0.7430 - val_loss: 0.7280 - learning_rate: 1.0000e-04
# Epoch 76/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7730 - loss: 0.6129 - val_accuracy: 0.7438 - val_loss: 0.7290 - learning_rate: 1.0000e-04
# Epoch 77/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7720 - loss: 0.6200 - val_accuracy: 0.7478 - val_loss: 0.7315 - learning_rate: 1.0000e-04
# Epoch 78/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7709 - loss: 0.6161 - val_accuracy: 0.7462 - val_loss: 0.7338 - learning_rate: 1.0000e-04
# Epoch 79/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7595 - loss: 0.6285 - val_accuracy: 0.7422 - val_loss: 0.7281 - learning_rate: 1.0000e-04
# Epoch 80/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7647 - loss: 0.6335 - val_accuracy: 0.7430 - val_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 81/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7726 - loss: 0.6060 - val_accuracy: 0.7470 - val_loss: 0.7283 - learning_rate: 1.0000e-04
# Epoch 82/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 42ms/step - accuracy: 0.7723 - loss: 0.6112 - val_accuracy: 0.7438 - val_loss: 0.7273 - learning_rate: 1.0000e-04
# Epoch 83/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7761 - loss: 0.6115 - val_accuracy: 0.7486 - val_loss: 0.7295 - learning_rate: 1.0000e-04
# Epoch 84/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 14s 41ms/step - accuracy: 0.7703 - loss: 0.6153 - val_accuracy: 0.7502 - val_loss: 0.7311 - learning_rate: 1.0000e-04
# Epoch 85/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 17s 49ms/step - accuracy: 0.7766 - loss: 0.6072 - val_accuracy: 0.7470 - val_loss: 0.7285 - learning_rate: 1.0000e-04
# Epoch 86/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7690 - loss: 0.6102 - val_accuracy: 0.7470 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 87/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.7738 - loss: 0.6143 - val_accuracy: 0.7430 - val_loss: 0.7290 - learning_rate: 1.0000e-04
# Epoch 88/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7720 - loss: 0.6141 - val_accuracy: 0.7446 - val_loss: 0.7292 - learning_rate: 1.0000e-04
# Epoch 89/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 16s 45ms/step - accuracy: 0.7809 - loss: 0.6070 - val_accuracy: 0.7454 - val_loss: 0.7279 - learning_rate: 1.0000e-04
# Epoch 90/150
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 15s 43ms/step - accuracy: 0.7751 - loss: 0.6073 - val_accuracy: 0.7454 - val_loss: 0.7306 - learning_rate: 1.0000e-04
# Epoch 90: early stopping
# Restoring model weights from the end of the best epoch: 70.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7529 - loss: 0.6703
# Test accuracy: 0.7495982050895691

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
